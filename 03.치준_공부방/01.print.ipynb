# %%
# 123234
# 3ㅁㄴ이ㅏㄹ
# ㄴ미러ㅣㄷㄹ

print("Hello, World!")
# Out:
# Hello, World!

# %%
print(5 + 3)
# Out:
# 8

# %%
print(type(5 + 3))
# Out:
# <class 'int'>

# %%
print(type("안녕하세요"))
# Out:
# <class 'str'>

# %%
print('"안녕하세요"라고 말했습니다')
# Out:
# "안녕하세요"라고 말했습니다

# %%
print("안녕하세요라고\n 말했습니다")
# Out:
# 안녕하세요라고
#  말했습니다

# %%
print("동해물과 백두산이 마르고 닳도록\n하느님이 보우하사 우리나라 만세")
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %%
print("""동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세""")
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %%
print("동해물과 백두산이 마르고 닳도록" +
" 하느님이 보우하사 우리나라 만세")
# Out:
# 동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세

# %%
print("동해물과 백두산이 마르고 닳도록" +
" 하느님이 보우하사 우리나라 만세"+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print("동해물과 백두산이 마르고 닳도록" +
#       2 " 하느님이 보우하사 우리나라 만세"+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('"안녕하세요"라고 말했습니다\n'*3)
# Out:
# "안녕하세요"라고 말했습니다
# "안녕하세요"라고 말했습니다
# "안녕하세요"라고 말했습니다

# %%
print("안녕하세요"[0])
print("안녕하세요"[1])
print("안녕하세요"[2])
print("안녕하세요"[3])
print("안녕하세요"[4])
# Out:
# 안
# 녕
# 하
# 세
# 요

# %%
print("기니다라마바사:abcdefg:123456"[0:7])
# Out:
# 기니다라마바사

# %%
print("기니다라마바사:abcdefg:123456"[:7])
# Out:
# 기니다라마바사

# %%
print("기니다라마바사:abcdefg:123456"[8:])
# Out:
# abcdefg:123456

# %%
print(len("기니다라마바사:abcdefg:123456"))
# Out:
# 22
