# %%
print( 10==100)
# Out:
# False

# %%
print(10!=100)
# Out:
# True

# %%
print(10<=100)
# Out:
# True

# %%
print(10>100)
# Out:
# False

# %%
print("송희섭"=="송치준")
# Out:
# False

# %%
print("송희섭"<"송치준")
# Out:
# False

# %%
print("송희섭">"송치준")
# Out:
# True

# %%
print(not True)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
number = input("정수입력>")
number = float(number)

if number > 0:
    print("양수입니다.")

if number < 0:
    print("음수입니다.")    
    
if number == 0: 
    print("0입니다.")
# Out:
# 음수입니다.

# %%
import datetime
now = datetime.datetime.now()
print(now)
print(now.year,"년")
print(now.month,"월")
print(now.day,"일")             
print(now.hour,"시")
print(now.minute,"분")
print(now.second,"초")
print(now.microsecond,"마이크로초")
# Out:
# 2026-02-22 18:44:56.403554
# 2026 년
# 2 월
# 22 일
# 18 시
# 44 분
# 56 초
# 403554 마이크로초

# %%
import datetime
now = datetime.datetime.now()
print("{}년 {}월 {}일 {}시 {}분 {}초".format(
    now.year, 
    now.month, 
    now.day, 
    now.hour, 
    now.minute, 
    now.second))
# Out:
# 2026년 2월 22일 18시 47분 0초

# %%
import datetime
now = datetime.datetime.now()

if now.hour < 12:
    print("오전입니다.")
if now.hour > 12:
    print("오후입니다.")
if now.hour == 12:
    print("정오입니다.")
# Out:
# 오후입니다.

# %%
import datetime
now = datetime.datetime.now()

if 3 <= now.month <= 5:
    print("봄입니다.")

if 6 <= now.month <= 8:
    print("여름입니다.")

if 9 <= now.month <= 11:
    print("가을입니다.")

if (now.month == 12) or (now.month <= 2):
    print("겨울입니다.")


# if ((now.month >= 3) and (now.month <= 5)) :
#     print("봄입니다.")
# Out:
# 겨울입니다.

# %%
import datetime
now = datetime.datetime.now()

if 3 <= now.month <= 5:
    print("봄입니다.")

elif 6 <= now.month <= 8:
    print("여름입니다.")

elif 9 <= now.month <= 11:
    print("가을입니다.")

elif (now.month == 12) or (now.month <= 2):
    print("겨울입니다.")
# Out:
# 겨울입니다.

# %%
import datetime
now = datetime.datetime.now()

if (now.month == 12) or (now.month <= 2):
    print("겨울입니다.")

elif 6 <= now.month <= 8:
    print("여름입니다.")

elif 9 <= now.month <= 11:
    print("가을입니다.")

elif 3 <= now.month <= 5:
    print("봄입니다.")
# Out:
# 겨울입니다.

# %%
print("# if 조건문에 0 넣기")
if 1:
    print("0은 참입니다.")
else:
    print("0은 거짓입니다.")
# Out:
# # if 조건문에 0 넣기
# 0은 참입니다.

# %%
number = input("정수입력>")
number = int(number)
if number > 0:
    # print("양수입니다.")
    raise NotImplementedError
else:
    # print("양수가 아닙니다.")
    raise NotImplementedError
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[53], line 5
#       2 number = int(number)
#       3 if number > 0:
#       4     # print("양수입니다.")
# ----> 5     raise NotImplementedError
#       6 else:
#       7     # print("양수가 아닙니다.")
#       8     raise NotImplementedError
#
# NotImplementedError:

# %%
array= [272, 32, 103, 57, 52, 103, 57, 52, 103, 57, 52 ]

array[2] = "안녕하세요."

print(array)
# Out:
# [272, 32, '안녕하세요.', 57, 52, 103, 57, 52, 103, 57, 52]

# %%
list_a = [[123, 32, 103],[57, 52, 103], [57, 52, 103, 57, 52 ]]
print(list_a[0][1])
print(list_a[1][2])
print(list_a[2][3])
# Out:
# 32
# 103
# 57

# %%
list_a = [273, 32, 103]
list_a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 list_a = [273, 32, 103]
# ----> 2 list_a[3]
#
# IndexError: list index out of range

# %%
list_a = [1, 2, 3]
list_b = [4, 5, 6]
print("list_a + list_b:", list_a + list_b)
# 0print("list_a * 3:", list_a * 3)
# print(len(list_a*3))
# print(len(list_a + list_b))
print("list_a ", list_a )
print("list_b ", list_b )

# list_a = list_a + list_b
# print("list_a + list_b:", list_a )
list_a.extend(list_b)
# print("list_a + list_b (extend):", list_a.extend(list_b) )
print("list_a + list_b(extend):", list_a )
# Out:
# list_a + list_b: [1, 2, 3, 4, 5, 6]
# list_a  [1, 2, 3]
# list_b  [4, 5, 6]
# list_a + list_b(extend): [1, 2, 3, 4, 5, 6]

# %%
list_a = [1, 2, 3]
list_a.insert(100,5)
print(list_a)
# list_a.append(4)
# print(list_a)
# Out:
# [1, 2, 3, 5]
