# %%
지역변수
전역변수
매개변수

# %%
strGlobal = "전역변수"

# def func(arg1 , arg2):
#     global strGlobal    
#     strLocal = "지역변수"
#     print(strGlobal)            # 전역변수 출력
#     print(strLocal)             # 지역변수 출력
#     print(arg1)                 # "매개변수1값" 출력
#     print(arg2)                 # "매개변수2값" 출력
#     strGlobal = arg1            
#     # strLocal = arg2     
        

# def func_a(arg1 , arg2):
#     strLocal22 = "지역변수22"
#     print(strLocal22)             # 지역변수 출력
#     strLocal22 = strLocal
   
def func_format(arg1 , arg2):
    strconcate = arg1 + " " + arg2
    print("func_format : " + strconcate)
    
    
func_format("매개변수1값", "매개변수2값")

str_format_func = "{} {}".format("매개변수1값", "매개변수2값")
print("str_format_func : " + str_format_func)


# func("매개변수1값", "매개변수2값")
# func_a("매개변수11값", "매개변수22값")

# print(strGlobal)
# print(strLocal)
# Out:
# func_format : 매개변수1값 매개변수2값
# str_format_func : 매개변수1값 매개변수2값

# %%
a=0
a= a+1
print(a)

a+=1
print(a)
# Out:
# 1
# 2

# %%
inputdata = input("a를 정해주세요: ")
# print(inputdata + 2)
# print(type(inputdata))
int(inputdata) #문자열을 숫자로 바꿔주는 함수
inputdata = int(inputdata)
print(inputdata + 2)

int_data= inputdata + 2
int_data = str(int_data)
print(type(int_data))
# Out:
# 3
# <class 'str'>

# %%
"{}".format(10)
# Out:
# '10'

# %%
format_a = "{}".format(10)
format_b = "{}만원 만들기".format(10)
format_c = "{}님은 {} {} 학생입니다.".format("송희섭","한양대학교","지능정보양자공학과")
format_d = "{}".format(10)

print(format_c)
# Out:
# 송희섭님은 한양대학교 지능정보양자공학과 학생입니다.

# %%
"{}".format(10)
"{}만원 만들기".format(10)
"{}님은 {} {} 학생입니다.".format("송치준","한양대학교","지능정보양자공학과")
"{}".format(10)
# Out:
# '10'

# %%
output_a = "{}".format(10)
print(output_a)
# Out:
# 10

# %%
output_a = "{:05d}".format(10)
print(output_a)

print(output_a)
print(output_a) 
print(output_a)
print(output_a)
print(output_a)
# Out:
#   Cell In[48], line 4
#     print(output_a) print(output_a)
#                     ^
# SyntaxError: invalid syntax

# %%
output_a = "{:05d}".format(52)
print(output_a)
# Out:
# 00052

# %%
output_a = "{:05d}".format(-52)
print(output_a)
# Out:
# -0052

# %%
a = "안녕"
b = a.upper()
print(b)
# Out:
# 안녕

# %%
a="      안녕하세요.     "
a = a.lstrip()
b = "111"
c = "222"
d = b + a + c
print(d)
# Out:
# 111안녕하세요.     222

# %%
a = "송희섭송치준김지현송치준".rfind("송치준")
print(a)
# Out:
# 9

# %%
print("송치준" in "송희섭송치준김지현송치준")
# Out:
# True

# %%
a  = "안:녕:하:세:요".split(":")
print(a)
# Out:
# ['안', '녕', '하', '세', '요']

# %%
a  = "11가34:22나56:33다78".
print(a)
