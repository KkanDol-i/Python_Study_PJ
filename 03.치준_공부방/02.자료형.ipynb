# %%
print(273)
print(273.1)
# Out:
# 273
# 273.1

# %%
print(type(273))
print(type(273.1))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print("5+7=",5+7)
print("5-7=",5-7)
print("5*7=",5*7)
print("5/7=",5/7)

print("5//7=",5//7)    # 몫 연산자
print("3//2=",3//2)

print("5%7=",5%7)    # 나머지 연산자
print("3%2=",3%2)
# Out:
# 5+7= 12
# 5-7= -2
# 5*7= 35
# 5/7= 0.7142857142857143
# 5//7= 0
# 3//2= 1
# 5%7= 5
# 3%2= 1
