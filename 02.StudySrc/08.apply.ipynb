# %%
import pandas as pd

col = ['col1','col2','col3']
row = ['row1','row2','row3']
data = [[1,2,3],[4,5,6],[7,8,9]]
df = pd.DataFrame(data=data,index=row,columns=col)
print(df)

# %%
print(df.apply(lambda x : [1,2,3]))
# Out:
#       col1  col2  col3
# row1     1     1     1
# row2     2     2     2
# row3     3     3     3

# %%
print(df.apply(lambda x : [1,2,3], axis=1,result_type='expand'))
# Out:
#       0  1  2
# row1  1  2  3
# row2  1  2  3
# row3  1  2  3

# %%
print(df.apply(lambda x : [1,2,3], axis=1,result_type='reduce'))
# Out:
# row1    [1, 2, 3]
# row2    [1, 2, 3]
# row3    [1, 2, 3]
# dtype: object

# %%
print(df.apply(lambda x : [1,2,3], axis=1,result_type='broadcast'))
# Out:
#       col1  col2  col3
# row1     1     2     3
# row2     1     2     3
# row3     1     2     3

# %%
col = ['col1','col2','col3']
row = ['row1','row2','row3']
data = [[1,2,3],[4,5,6],[7,pd.NA,9]]
df = pd.DataFrame(data=data,index=row,columns=col)
print(df)
# Out:
#       col1  col2  col3
# row1     1     2     3
# row2     4     5     6
# row3     7  <NA>     9

# %%
# print(df.applymap(lambda x : x**2,na_action='ignore'))    applymap 미사용으로 map으로 대체
print(df.map(lambda x : x**2,na_action='ignore'))
# Out:
#       col1  col2  col3
# row1     1     4     9
# row2    16    25    36
# row3    49  <NA>    81
